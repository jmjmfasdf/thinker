# %%
import numpy as np

# %%
data = np.load('pong_3e6_sub1_game1_day1_block1_episode0_17872/sub1-game1-day1-block1-episode0-17872.npz')

# %%
data.keys()
# Out:
# KeysView(NpzFile 'pong_3e6_sub1_game1_day1_block1_episode0_17872/sub1-game1-day1-block1-episode0-17872.npz' with keys: planning_depth, action_diversity, imagination_diversity, imagination_similarity, action)
